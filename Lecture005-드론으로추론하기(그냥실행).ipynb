# %% [markdown]
# <img src='https://www.anadronestarting.com/wp-content/uploads/intel-main_opt.png' width=40%>
#
# # Lecture 005. 드론으로 추론하기_원본
#
# <font size=5><div align='right'>이  인  구 (Ike Lee)</div>
# <font size=5><div align='right'>이  해  영 (Haeyoung Lee)</div>
#
# <img src='https://images.crutchfieldonline.com/ImageHandler/trim/620/378/products/2019/33/964/g964TELLEDU-F.jpg' width=40%>
#
# ---

# %% [markdown]
# #### 드론조종기1.py
# 드론조종기1은 일반적인 드론을 조종하는 코드입니다.(스크립트대로 드론 이동x)
# #### 드론조종기2.py
# 드론조종기2는 드론이 우리가 훈련시킨 모델의 사물을 발견했을 때 사용자가 작성한 스크립트대로 드론이 움직이게 해주는 코드입니다.
# #### 드론조종기3.py
# 드론조종기3은 원본 모델로 어떤 물체를 발견했을 때 사용자가 작성한 스크립트대로 드론이 움직이게 해주는 코드입니다.

# %% [markdown]
# ### 드론이 사용할 모델 가져오기

# %%
# %cd bin2
# %cp -f mobilenetv2.xml mobilenetv2.bin mobilenetv2.txt /home/intel/imobilenet/인공지능드론/models
# Out:
# /home/intel/test/bin2
# cp: target '/home/intel/imobilenet/인공지능드론/models' is not a directory

# %% [markdown]
# ### 명령창에서 드론 창 실행하기

# %%
# %cd /home/intel/test/인공지능드론
! python3 드론조종기1.py True
# Out:
# /home/intel/test/인공지능드론
# Object Detector initialize...
# /home/intel/test/인공지능드론/ObjectClassifier_Cifar10.py:32: DeprecationWarning: Reading network using constructor is deprecated. Please, use IECore.read_network() method instead
#   net = IENetwork(model=model_xml, weights=model_bin)
# /home/intel/test/인공지능드론/ObjectClassifier_Cifar10.py:33: DeprecationWarning: 'inputs' property of IENetwork class is deprecated. To access DataPtrs user need to use 'input_data' property of InputInfoPtr objects which can be accessed by 'input_info' property.
#   assert len(net.inputs.keys()) == 1
# GPU
# /home/intel/test/인공지능드론/ObjectClassifier_Cifar10.py:37: DeprecationWarning: IEPlugin class is deprecated. Please use IECore class instead.
#   plugin = IEPlugin(device=device)
# <class 'openvino.inference_engine.ie_api.IEPlugin'>
# Loading IR to the plugin...
# 1 3 224 224
# Main socket binding ip : 192.168.10.2:8889
# State socket binding ip : 0.0.0.0:8890
# Traceback (most recent call last):
#   File "/home/intel/test/인공지능드론/tello.py", line 50, in receive_process
#     self.response = response.decode('utf-8')
# UnicodeDecodeError: 'utf-8' codec can't decode byte 0xcc in position 0: invalid continuation byte
# catch error
# [h264 @ 0x7f2be456b660] non-existing PPS 0 referenced
# [h264 @ 0x7f2be456b660] non-existing PPS 0 referenced
# [h264 @ 0x7f2be456b660] decode_slice_header error
# [h264 @ 0x7f2be456b660] no frame!
# [h264 @ 0x7f2be456b660] non-existing PPS 0 referenced
# [h264 @ 0x7f2be456b660] non-existing PPS 0 referenced
# [h264 @ 0x7f2be456b660] decode_slice_header error
# [h264 @ 0x7f2be456b660] no frame!
# [h264 @ 0x7f2be456b660] non-existing PPS 0 referenced
# [h264 @ 0x7f2be456b660] non-existing PPS 0 referenced
# [h264 @ 0x7f2be456b660] decode_slice_header error
# [h264 @ 0x7f2be456b660] no frame!
# [h264 @ 0x7f2be456b660] non-existing PPS 0 referenced
# [h264 @ 0x7f2be456b660] non-existing PPS 0 referenced
# [h264 @ 0x7f2be456b660] decode_slice_header error
# [h264 @ 0x7f2be456b660] no frame!
# [h264 @ 0x7f2be456b660] non-existing PPS 0 referenced
# [h264 @ 0x7f2be456b660] non-existing PPS 0 referenced
# [h264 @ 0x7f2be456b660] decode_slice_header error
# [h264 @ 0x7f2be456b660] no frame!
# [h264 @ 0x7f2be456b660] non-existing PPS 0 referenced
# [h264 @ 0x7f2be456b660] non-existing PPS 0 referenced
# [h264 @ 0x7f2be456b660] decode_slice_header error
# [h264 @ 0x7f2be456b660] no frame!
# [h264 @ 0x7f2be456b660] non-existing PPS 0 referenced
# [h264 @ 0x7f2be456b660] non-existing PPS 0 referenced
# [h264 @ 0x7f2be456b660] decode_slice_header error
# [h264 @ 0x7f2be456b660] no frame!
# [h264 @ 0x7f2be456b660] non-existing PPS 0 referenced
# [h264 @ 0x7f2be456b660] non-existing PPS 0 referenced
# [h264 @ 0x7f2be456b660] decode_slice_header error
# [h264 @ 0x7f2be456b660] no frame!
# [h264 @ 0x7f2be456b660] non-existing PPS 0 referenced
# [h264 @ 0x7f2be456b660] non-existing PPS 0 referenced
# [h264 @ 0x7f2be456b660] decode_slice_header error
# [h264 @ 0x7f2be456b660] no frame!
# [h264 @ 0x7f2be456b660] non-existing PPS 0 referenced
# [h264 @ 0x7f2be456b660] non-existing PPS 0 referenced
# [h264 @ 0x7f2be456b660] decode_slice_header error
# [h264 @ 0x7f2be456b660] no frame!
# [h264 @ 0x7f2be456b660] non-existing PPS 0 referenced
# [h264 @ 0x7f2be456b660] non-existing PPS 0 referenced
# [h264 @ 0x7f2be456b660] decode_slice_header error
# [h264 @ 0x7f2be456b660] no frame!
# [h264 @ 0x7f2be456b660] non-existing PPS 0 referenced
# [h264 @ 0x7f2be456b660] non-existing PPS 0 referenced
# [h264 @ 0x7f2be456b660] decode_slice_header error
# [h264 @ 0x7f2be456b660] no frame!
# [h264 @ 0x7f2be456b660] non-existing PPS 0 referenced
# [h264 @ 0x7f2be456b660] non-existing PPS 0 referenced
# [h264 @ 0x7f2be456b660] decode_slice_header error
# [h264 @ 0x7f2be456b660] no frame!
# [h264 @ 0x7f2be456b660] non-existing PPS 0 referenced
# [h264 @ 0x7f2be456b660] non-existing PPS 0 referenced
# [h264 @ 0x7f2be456b660] decode_slice_header error
# [h264 @ 0x7f2be456b660] no frame!
# [h264 @ 0x7f2be456b660] non-existing PPS 0 referenced
# [h264 @ 0x7f2be456b660] non-existing PPS 0 referenced
# [h264 @ 0x7f2be456b660] decode_slice_header error
# [h264 @ 0x7f2be456b660] no frame!
# [h264 @ 0x7f2be456b660] non-existing PPS 0 referenced
# [h264 @ 0x7f2be456b660] non-existing PPS 0 referenced
# [h264 @ 0x7f2be456b660] decode_slice_header error
# [h264 @ 0x7f2be456b660] no frame!
# [h264 @ 0x7f2be456b660] non-existing PPS 0 referenced
# [h264 @ 0x7f2be456b660] non-existing PPS 0 referenced
# [h264 @ 0x7f2be456b660] decode_slice_header error
# [h264 @ 0x7f2be456b660] no frame!
# [h264 @ 0x7f2be456b660] non-existing PPS 0 referenced
# [h264 @ 0x7f2be456b660] non-existing PPS 0 referenced
# [h264 @ 0x7f2be456b660] decode_slice_header error
# [h264 @ 0x7f2be456b660] no frame!
# [h264 @ 0x7f2be456b660] non-existing PPS 0 referenced
# [h264 @ 0x7f2be456b660] non-existing PPS 0 referenced
# [h264 @ 0x7f2be456b660] decode_slice_header error
# [h264 @ 0x7f2be456b660] no frame!
# [h264 @ 0x7f2be456b660] non-existing PPS 0 referenced
# [h264 @ 0x7f2be456b660] non-existing PPS 0 referenced
# [h264 @ 0x7f2be456b660] decode_slice_header error
# [h264 @ 0x7f2be456b660] no frame!
# [h264 @ 0x7f2be456b660] non-existing PPS 0 referenced
# [h264 @ 0x7f2be456b660] non-existing PPS 0 referenced
# [h264 @ 0x7f2be456b660] decode_slice_header error
# [h264 @ 0x7f2be456b660] no frame!
# [h264 @ 0x7f2be456b660] non-existing PPS 0 referenced
# [h264 @ 0x7f2be456b660] non-existing PPS 0 referenced
# [h264 @ 0x7f2be456b660] decode_slice_header error
# [h264 @ 0x7f2be456b660] no frame!
# [h264 @ 0x7f2be456b660] non-existing PPS 0 referenced
# [h264 @ 0x7f2be456b660] non-existing PPS 0 referenced
# [h264 @ 0x7f2be456b660] decode_slice_header error
# [h264 @ 0x7f2be456b660] no frame!
# [h264 @ 0x7f2be456b660] non-existing PPS 0 referenced
# [h264 @ 0x7f2be456b660] non-existing PPS 0 referenced
# [h264 @ 0x7f2be456b660] decode_slice_header error
# [h264 @ 0x7f2be456b660] no frame!
# [h264 @ 0x7f2be456b660] non-existing PPS 0 referenced
# [h264 @ 0x7f2be456b660] non-existing PPS 0 referenced
# [h264 @ 0x7f2be456b660] decode_slice_header error
# [h264 @ 0x7f2be456b660] no frame!
# [h264 @ 0x7f2be456b660] non-existing PPS 0 referenced
# [h264 @ 0x7f2be456b660] non-existing PPS 0 referenced
# [h264 @ 0x7f2be456b660] decode_slice_header error
# [h264 @ 0x7f2be456b660] no frame!
# [h264 @ 0x7f2be456b660] non-existing PPS 0 referenced
# [h264 @ 0x7f2be456b660] non-existing PPS 0 referenced
# [h264 @ 0x7f2be456b660] decode_slice_header error
# [h264 @ 0x7f2be456b660] no frame!
# [h264 @ 0x7f2be456b660] non-existing PPS 0 referenced
# [h264 @ 0x7f2be456b660] non-existing PPS 0 referenced
# [h264 @ 0x7f2be456b660] decode_slice_header error
# [h264 @ 0x7f2be456b660] no frame!
# [h264 @ 0x7f2be4975a20] error while decoding MB 9 36, bytestream -6
# [h264 @ 0x7f2be4ad77a0] left block unavailable for requested intra mode
# [h264 @ 0x7f2be4ad77a0] error while decoding MB 0 37, bytestream 1856
# [h264 @ 0x7f2be4920400] left block unavailable for requested intra4x4 mode -1
# [h264 @ 0x7f2be4920400] error while decoding MB 0 27, bytestream 4667
# [h264 @ 0x7f2be4aadea0] left block unavailable for requested intra4x4 mode -1
# [h264 @ 0x7f2be4aadea0] error while decoding MB 0 36, bytestream 2039
# [h264 @ 0x7f2be494f440] left block unavailable for requested intra4x4 mode -1
# [h264 @ 0x7f2be494f440] error while decoding MB 0 36, bytestream 2237
# [h264 @ 0x7f2be4ad77a0] left block unavailable for requested intra4x4 mode -1
# [h264 @ 0x7f2be4ad77a0] error while decoding MB 0 42, bytestream 838
# [h264 @ 0x7f2be494f440] left block unavailable for requested intra mode
# [h264 @ 0x7f2be494f440] error while decoding MB 0 40, bytestream 1218
# [h264 @ 0x7f2be4aadea0] error while decoding MB 12 36, bytestream -6
# [h264 @ 0x7f2be4ad77a0] left block unavailable for requested intra mode
# [h264 @ 0x7f2be4ad77a0] error while decoding MB 0 24, bytestream 5385
# [h264 @ 0x7f2be494f440] left block unavailable for requested intra4x4 mode -1
# [h264 @ 0x7f2be494f440] error while decoding MB 0 29, bytestream 4317
# Traceback (most recent call last):
#   File "드론조종기1.py", line 286, in orderLoad
#     f = open(filename, 'r')
# FileNotFoundError: [Errno 2] No such file or directory: './scripts/begine'
# [h264 @ 0x7f2be4ad77a0] left block unavailable for requested intra mode
# [h264 @ 0x7f2be4ad77a0] error while decoding MB 0 39, bytestream 2181
# [h264 @ 0x7f2be494f440] left block unavailable for requested intra mode
# [h264 @ 0x7f2be494f440] error while decoding MB 0 24, bytestream 5318
# [h264 @ 0x7f2be4975a20] left block unavailable for requested intra mode
# [h264 @ 0x7f2be4975a20] error while decoding MB 0 30, bytestream 3935
# [h264 @ 0x7f2be4579e00] left block unavailable for requested intra4x4 mode -1
# [h264 @ 0x7f2be4579e00] error while decoding MB 0 38, bytestream 3105
# [h264 @ 0x7f2be4ad77a0] left block unavailable for requested intra mode
# [h264 @ 0x7f2be4ad77a0] error while decoding MB 0 41, bytestream 1727
# [h264 @ 0x7f2be494f440] left block unavailable for requested intra4x4 mode -1
# [h264 @ 0x7f2be494f440] error while decoding MB 0 40, bytestream 1428
# [h264 @ 0x7f2be4975a20] error while decoding MB 43 31, bytestream -8
# [h264 @ 0x7f2be4919cc0] left block unavailable for requested intra mode
# [h264 @ 0x7f2be4919cc0] error while decoding MB 0 42, bytestream 1455
# [h264 @ 0x7f2be494f440] left block unavailable for requested intra mode
# [h264 @ 0x7f2be494f440] error while decoding MB 0 32, bytestream 5954
# [h264 @ 0x7f2be4579e00] left block unavailable for requested intra mode
# [h264 @ 0x7f2be4579e00] error while decoding MB 0 35, bytestream 4545
# [h264 @ 0x7f2be494f440] left block unavailable for requested intra mode
# [h264 @ 0x7f2be494f440] error while decoding MB 0 31, bytestream 3716
# [h264 @ 0x7f2be4975a20] left block unavailable for requested intra mode
# [h264 @ 0x7f2be4975a20] error while decoding MB 0 39, bytestream 1432
# [h264 @ 0x7f2be4975a20] error while decoding MB 52 31, bytestream -8
# [h264 @ 0x7f2be4579e00] left block unavailable for requested intra4x4 mode -1
# [h264 @ 0x7f2be4579e00] error while decoding MB 0 38, bytestream 3087
# [h264 @ 0x7f2be4579e00] left block unavailable for requested intra mode
# [h264 @ 0x7f2be4579e00] error while decoding MB 0 41, bytestream 1641
# [h264 @ 0x7f2be4ad77a0] left block unavailable for requested intra mode
# [h264 @ 0x7f2be4ad77a0] error while decoding MB 0 41, bytestream 1607
# [h264 @ 0x7f2be4919cc0] left block unavailable for requested intra mode
# [h264 @ 0x7f2be4919cc0] error while decoding MB 0 38, bytestream 3007
# [h264 @ 0x7f2be4ad77a0] left block unavailable for requested intra mode
# [h264 @ 0x7f2be4ad77a0] error while decoding MB 0 39, bytestream 1669
# [h264 @ 0x7f2be4579e00] left block unavailable for requested intra mode
# [h264 @ 0x7f2be4579e00] error while decoding MB 0 35, bytestream 4386
# [h264 @ 0x7f2be4579e00] left block unavailable for requested intra4x4 mode -1
# [h264 @ 0x7f2be4579e00] error while decoding MB 0 38, bytestream 1925
# [h264 @ 0x7f2be4919cc0] left block unavailable for requested intra4x4 mode -1
# [h264 @ 0x7f2be4919cc0] error while decoding MB 0 38, bytestream 2975
# [h264 @ 0x7f2be4ad77a0] left block unavailable for requested intra4x4 mode -1
# [h264 @ 0x7f2be4ad77a0] error while decoding MB 0 38, bytestream 2980
# [h264 @ 0x7f2be4aadea0] error while decoding MB 59 31, bytestream -6
# [h264 @ 0x7f2be494f440] left block unavailable for requested intra4x4 mode -1
# [h264 @ 0x7f2be494f440] error while decoding MB 0 41, bytestream 1643
# [h264 @ 0x7f2be4579e00] left block unavailable for requested intra mode
# [h264 @ 0x7f2be4579e00] error while decoding MB 0 35, bytestream 4389
# [h264 @ 0x7f2be4920400] error while decoding MB 51 36, bytestream -10
# [h264 @ 0x7f2be4919cc0] left block unavailable for requested intra4x4 mode -1
# [h264 @ 0x7f2be4919cc0] error while decoding MB 0 35, bytestream 4393
# [h264 @ 0x7f2be4aadea0] error while decoding MB 59 26, bytestream -16
# [h264 @ 0x7f2be494f440] left block unavailable for requested intra mode
# [h264 @ 0x7f2be494f440] error while decoding MB 0 38, bytestream 2996
# [h264 @ 0x7f2be4ad77a0] error while decoding MB 13 44, bytestream -8
# [h264 @ 0x7f2be494f440] left block unavailable for requested intra mode
# [h264 @ 0x7f2be494f440] error while decoding MB 0 41, bytestream 1102
# [h264 @ 0x7f2be4ad77a0] left block unavailable for requested intra4x4 mode -1
# [h264 @ 0x7f2be4ad77a0] error while decoding MB 0 38, bytestream 2985
# [h264 @ 0x7f2be4579e00] left block unavailable for requested intra mode
# [h264 @ 0x7f2be4579e00] error while decoding MB 0 44, bytestream 475
# [h264 @ 0x7f2be4579e00] left block unavailable for requested intra mode
# [h264 @ 0x7f2be4579e00] error while decoding MB 0 35, bytestream 4521
# [h264 @ 0x7f2be4919cc0] left block unavailable for requested intra4x4 mode -1
# [h264 @ 0x7f2be4919cc0] error while decoding MB 0 32, bytestream 5898
# [h264 @ 0x7f2be494f440] left block unavailable for requested intra mode
# [h264 @ 0x7f2be494f440] error while decoding MB 0 38, bytestream 2973
# [h264 @ 0x7f2be4919cc0] left block unavailable for requested intra mode
# [h264 @ 0x7f2be4919cc0] error while decoding MB 0 35, bytestream 2386
# [h264 @ 0x7f2be4919cc0] left block unavailable for requested intra4x4 mode -1
# [h264 @ 0x7f2be4919cc0] error while decoding MB 0 35, bytestream 4374
# [h264 @ 0x7f2be4579e00] left block unavailable for requested intra4x4 mode -1
# [h264 @ 0x7f2be4579e00] error while decoding MB 0 39, bytestream 2576
# [h264 @ 0x7f2be4aa25c0] left block unavailable for requested intra mode
# [h264 @ 0x7f2be4aa25c0] error while decoding MB 0 36, bytestream 3139
# [h264 @ 0x7f2be4920400] error while decoding MB 48 41, bytestream -6
# [h264 @ 0x7f2be4975a20] error while decoding MB 54 41, bytestream -8
# [h264 @ 0x7f2be4975a20] error while decoding MB 47 41, bytestream -6
# [h264 @ 0x7f2be4920400] error while decoding MB 59 31, bytestream -18
# [h264 @ 0x7f2be4aa25c0] error while decoding MB 2 31, bytestream -8
# [h264 @ 0x7f2be4975a20] error while decoding MB 48 37, bytestream -6
# [h264 @ 0x7f2be4aadea0] error while decoding MB 51 41, bytestream -6
# [h264 @ 0x7f2be494f440] left block unavailable for requested intra4x4 mode -1
# [h264 @ 0x7f2be494f440] error while decoding MB 0 37, bytestream 3286
# [h264 @ 0x7f2be4aa25c0] error while decoding MB 45 36, bytestream -6
# [h264 @ 0x7f2be4ad77a0] left block unavailable for requested intra mode
# [h264 @ 0x7f2be4ad77a0] error while decoding MB 0 41, bytestream 1594
# [h264 @ 0x7f2be4919cc0] left block unavailable for requested intra4x4 mode -1
# [h264 @ 0x7f2be4919cc0] error while decoding MB 0 34, bytestream 4818
# [h264 @ 0x7f2be4aadea0] error while decoding MB 18 30, bytestream -8
# [h264 @ 0x7f2be4579e00] left block unavailable for requested intra4x4 mode -1
# [h264 @ 0x7f2be4579e00] error while decoding MB 0 41, bytestream 1618
# [h264 @ 0x7f2be4975a20] error while decoding MB 35 25, bytestream -6
# [h264 @ 0x7f2be4aa25c0] error while decoding MB 35 41, bytestream -6
# [h264 @ 0x7f2be4579e00] left block unavailable for requested intra mode
# [h264 @ 0x7f2be4579e00] error while decoding MB 0 41, bytestream 1286
# [h264 @ 0x7f2be4919cc0] left block unavailable for requested intra mode
# [h264 @ 0x7f2be4919cc0] error while decoding MB 0 38, bytestream 2881
# [h264 @ 0x7f2be4920400] error while decoding MB 11 31, bytestream -6
# [h264 @ 0x7f2be494f440] left block unavailable for requested intra mode
# [h264 @ 0x7f2be494f440] error while decoding MB 0 41, bytestream 1631
# [h264 @ 0x7f2be4aa25c0] error while decoding MB 3 26, bytestream -8
# [h264 @ 0x7f2be4ad77a0] left block unavailable for requested intra mode
# [h264 @ 0x7f2be4ad77a0] error while decoding MB 0 38, bytestream 2943
# [h264 @ 0x7f2be4975a20] error while decoding MB 3 31, bytestream -8
# [h264 @ 0x7f2be4aadea0] error while decoding MB 55 25, bytestream -6
# [h264 @ 0x7f2be494f440] left block unavailable for requested intra4x4 mode -1
# [h264 @ 0x7f2be494f440] error while decoding MB 0 35, bytestream 4297
# [h264 @ 0x7f2be4ad77a0] left block unavailable for requested intra mode
# [h264 @ 0x7f2be4ad77a0] error while decoding MB 0 38, bytestream 2893
# [h264 @ 0x7f2be4aadea0] error while decoding MB 40 41, bytestream -6
# [h264 @ 0x7f2be494f440] left block unavailable for requested intra mode
# [h264 @ 0x7f2be494f440] error while decoding MB 0 41, bytestream 1593
# [h264 @ 0x7f2be4579e00] left block unavailable for requested intra4x4 mode -1
# [h264 @ 0x7f2be4579e00] error while decoding MB 0 33, bytestream 5652
# [h264 @ 0x7f2be4ad77a0] left block unavailable for requested intra mode
# [h264 @ 0x7f2be4ad77a0] error while decoding MB 0 42, bytestream 1250
# [h264 @ 0x7f2be4920400] error while decoding MB 2 37, bytestream -8
# [h264 @ 0x7f2be4ad77a0] error while decoding MB 23 34, bytestream 4172
# [h264 @ 0x7f2be4919cc0] left block unavailable for requested intra4x4 mode -1
# [h264 @ 0x7f2be4919cc0] error while decoding MB 0 42, bytestream 1131
# [h264 @ 0x7f2be4ad77a0] left block unavailable for requested intra mode
# [h264 @ 0x7f2be4ad77a0] error while decoding MB 0 32, bytestream 5713
# [h264 @ 0x7f2be4975a20] error while decoding MB 20 31, bytestream -8
# [h264 @ 0x7f2be494f440] left block unavailable for requested intra4x4 mode -1
# [h264 @ 0x7f2be494f440] error while decoding MB 0 32, bytestream 5718
# [h264 @ 0x7f2be4919cc0] left block unavailable for requested intra4x4 mode -1
# [h264 @ 0x7f2be4919cc0] error while decoding MB 0 35, bytestream 4336
# [h264 @ 0x7f2be4ad77a0] left block unavailable for requested intra4x4 mode -1
# [h264 @ 0x7f2be4ad77a0] error while decoding MB 0 35, bytestream 4304
# [h264 @ 0x7f2be4975a20] error while decoding MB 12 31, bytestream -10
# [h264 @ 0x7f2be4919cc0] left block unavailable for requested intra4x4 mode -1
# [h264 @ 0x7f2be4919cc0] error while decoding MB 0 38, bytestream 2870
# [h264 @ 0x7f2be494f440] left block unavailable for requested intra4x4 mode -1
# [h264 @ 0x7f2be494f440] error while decoding MB 0 32, bytestream 5680
# [h264 @ 0x7f2be494f440] left block unavailable for requested intra4x4 mode -1
# [h264 @ 0x7f2be494f440] error while decoding MB 0 36, bytestream 3963
# [h264 @ 0x7f2be4919cc0] left block unavailable for requested intra mode
# [h264 @ 0x7f2be4919cc0] error while decoding MB 0 36, bytestream 3887
# [h264 @ 0x7f2be4aadea0] error while decoding MB 18 31, bytestream -10
# [h264 @ 0x7f2be494f440] left block unavailable for requested intra4x4 mode -1
# [h264 @ 0x7f2be494f440] error while decoding MB 0 35, bytestream 4340
# [h264 @ 0x7f2be4919cc0] left block unavailable for requested intra4x4 mode -1
# [h264 @ 0x7f2be4919cc0] error while decoding MB 0 38, bytestream 2905
# [h264 @ 0x7f2be4919cc0] left block unavailable for requested intra4x4 mode -1
# [h264 @ 0x7f2be4919cc0] error while decoding MB 0 42, bytestream 1180
# [h264 @ 0x7f2be494f440] left block unavailable for requested intra4x4 mode -1
# [h264 @ 0x7f2be494f440] error while decoding MB 0 35, bytestream 4299
# [h264 @ 0x7f2be4aa25c0] left block unavailable for requested intra mode
# [h264 @ 0x7f2be4aa25c0] error while decoding MB 0 28, bytestream 5769
# [h264 @ 0x7f2be4aadea0] left block unavailable for requested intra mode
# [h264 @ 0x7f2be4aadea0] error while decoding MB 0 13, bytestream 8651
# [h264 @ 0x7f2be4aa25c0] error while decoding MB 19 42, bytestream -6
# [h264 @ 0x7f2be4ad77a0] error while decoding MB 48 44, bytestream -10
# [h264 @ 0x7f2be4920400] error while decoding MB 4 30, bytestream -6
# [h264 @ 0x7f2be4aa25c0] error while decoding MB 22 33, bytestream -8
# [h264 @ 0x7f2be4975a20] error while decoding MB 9 33, bytestream -8
# [h264 @ 0x7f2be4919cc0] left block unavailable for requested intra4x4 mode -1
# [h264 @ 0x7f2be4919cc0] error while decoding MB 0 39, bytestream 2934
# [h264 @ 0x7f2be4aa25c0] error while decoding MB 41 44, bytestream -10
# [h264 @ 0x7f2be4aa25c0] error while decoding MB 52 41, bytestream -10
# [h264 @ 0x7f2be4ad77a0] left block unavailable for requested intra mode
# [h264 @ 0x7f2be4ad77a0] error while decoding MB 0 43, bytestream 1149
# [h264 @ 0x7f2be494f440] error while decoding MB 51 44, bytestream -6
# [h264 @ 0x7f2be4975a20] error while decoding MB 11 40, bytestream -12
